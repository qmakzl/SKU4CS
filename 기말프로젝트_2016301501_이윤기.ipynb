# %%
import pandas as pd
import numpy as np
from glob import glob
import matplotlib.pyplot as plt 
from matplotlib import font_manager, rc 
# %matplotlib inline

font_path='C:/Windows/Fonts/malgun.ttf' 
font_name= font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# %%
def modify_data(df):
    target_cols=df.iloc[15].values
    change_cols=dict( [(org,new) for org, new in  zip(df.columns, target_cols)])
    df.rename( columns=change_cols, inplace=True)
    df= df[16:]
    df.reset_index(drop=True, inplace=True)
    return df

# %%
op_df=pd.read_excel('./오피스텔_실거래가_20191215.xlsx', encoding='euc-kr')
op_df.head(20)
# Out:
#    □ 본 서비스에서 제공하는 정보는 법적인 효력이 없으므로 참고용으로만 활용하시기 바랍니다. Unnamed: 1 Unnamed: 2  \
# 0   □ 신고정보가 실시간 변경, 해제되어 제공시점에 따라 공개건수 및 내용이 상이할 수...        NaN        NaN
# 1   □ 본 자료는 계약일 기준입니다. (※ 7월 계약, 8월 신고건 → 7월 거래건으로...        NaN        NaN
# 2   □ 통계자료 활용시에는 수치가 왜곡될 수 있으니 참고자료로만 활용하시기  바라며, ...        NaN        NaN
# 3   * 주택매매 거래는 부동산 거래신고 등에 관한 법률 제3조에 따라 계약일로부터 60...        NaN        NaN
# 4   * 국토교통부 실거래가 공개시스템의 궁금하신 점이나 문의사항은 콜센터 1588-01...        NaN        NaN
# 5                                              □ 검색조건        NaN        NaN
# 6                          계약일자 : 20190101 ~ 20191130        NaN        NaN
# 7                                  실거래 구분 : 오피스텔(전월세)        NaN        NaN
# 8                                         주소구분 : 지번주소        NaN        NaN
# 9                                          시도 : 서울특별시        NaN        NaN
# 10                                           시군구 : 전체        NaN        NaN
# ...

# %%
result_op_df=modify_data(op_df)
result_op_df.head(5)
# Out:
#              시군구      번지    본번    부번          단지명 전월세구분 전용면적(㎡)    계약년월 계약일  \
# 0  서울특별시 강남구 개포동   157-9  0157  0009  \t(157-9)\t    월세   36.96  201905   9
# 1  서울특별시 강남구 개포동   157-9  0157  0009  \t(157-9)\t    전세   36.96  201911   1
# 2  서울특별시 강남구 개포동  1229-6  1229  0006     CCRU오피스텔    전세   22.12  201911  20
# 3  서울특별시 강남구 개포동  1237-8  1237  0008        YH빌리지    전세   37.41  201911   7
# 4  서울특별시 강남구 개포동    13-3  0013  0003         대청타워    전세   37.55  201902  16
#
#           보증금(만원)          월세(만원)   층  건축년도        도로명
# 0           2,000              75   3  2011   선릉로4길 19
# 1          20,000               0   3  2011   선릉로4길 19
# 2          18,000               0   4  2019     논현로 78
# 3          28,000               0   2  2017  논현로20길 22
# 4          16,000               0  22  1997    개포로 623

# %%
ap_df=pd.read_excel('./아파트_실거래가_20191215.xlsx', encoding='euc-kr')
ap_df.head(20)
# Out:
#    □ 본 서비스에서 제공하는 정보는 법적인 효력이 없으므로 참고용으로만 활용하시기 바랍니다. Unnamed: 1 Unnamed: 2  \
# 0   □ 신고정보가 실시간 변경, 해제되어 제공시점에 따라 공개건수 및 내용이 상이할 수...        NaN        NaN
# 1   □ 본 자료는 계약일 기준입니다. (※ 7월 계약, 8월 신고건 → 7월 거래건으로...        NaN        NaN
# 2   □ 통계자료 활용시에는 수치가 왜곡될 수 있으니 참고자료로만 활용하시기  바라며, ...        NaN        NaN
# 3   * 주택매매 거래는 부동산 거래신고 등에 관한 법률 제3조에 따라 계약일로부터 60...        NaN        NaN
# 4   * 국토교통부 실거래가 공개시스템의 궁금하신 점이나 문의사항은 콜센터 1588-01...        NaN        NaN
# 5                                              □ 검색조건        NaN        NaN
# 6                          계약일자 : 20190101 ~ 20191130        NaN        NaN
# 7                                   실거래 구분 : 아파트(전월세)        NaN        NaN
# 8                                         주소구분 : 지번주소        NaN        NaN
# 9                                          시도 : 서울특별시        NaN        NaN
# 10                                           시군구 : 전체        NaN        NaN
# ...

# %%
result_ap_df=modify_data(ap_df)
result_ap_df.head(5)
# Out:
#              시군구     번지    본번    부번             단지명 전월세구분 전용면적(㎡)    계약년월 계약일  \
# 0  서울특별시 강남구 개포동  655-2  0655  0002  개포2차현대아파트(220)    월세   77.75  201901  29
# 1  서울특별시 강남구 개포동  655-2  0655  0002  개포2차현대아파트(220)    전세   77.75  201903  23
# 2  서울특별시 강남구 개포동  655-2  0655  0002  개포2차현대아파트(220)    전세   77.75  201904   2
# 3  서울특별시 강남구 개포동  655-2  0655  0002  개포2차현대아파트(220)    전세   77.75  201907  23
# 4  서울특별시 강남구 개포동  655-2  0655  0002  개포2차현대아파트(220)    전세   77.75  201908  24
#
#           보증금(만원)          월세(만원)  층  건축년도      도로명
# 0          36,000              60  8  1988  언주로 103
# 1          50,000               0  9  1988  언주로 103
# 2          50,000               0  5  1988  언주로 103
# 3          60,000               0  4  1988  언주로 103
# 4          50,000               0  9  1988  언주로 103

# %%
sum_df = pd.concat([result_op_df, result_ap_df], keys=['result_op_df','result_ap_df']) #2개를 합침
sum_df.head(5)
# Out:
#                           시군구      번지    본번    부번          단지명 전월세구분 전용면적(㎡)  \
# result_op_df 0  서울특별시 강남구 개포동   157-9  0157  0009  \t(157-9)\t    월세   36.96
#              1  서울특별시 강남구 개포동   157-9  0157  0009  \t(157-9)\t    전세   36.96
#              2  서울특별시 강남구 개포동  1229-6  1229  0006     CCRU오피스텔    전세   22.12
#              3  서울특별시 강남구 개포동  1237-8  1237  0008        YH빌리지    전세   37.41
#              4  서울특별시 강남구 개포동    13-3  0013  0003         대청타워    전세   37.55
#
#                   계약년월 계약일         보증금(만원)          월세(만원)   층  건축년도  \
# result_op_df 0  201905   9           2,000              75   3  2011
#              1  201911   1          20,000               0   3  2011
#              2  201911  20          18,000               0   4  2019
#              3  201911   7          28,000               0   2  2017
#              4  201902  16          16,000               0  22  1997
#
#                       도로명
# result_op_df 0   선릉로4길 19
#              1   선릉로4길 19
# ...

# %%
del sum_df["번지"]
del sum_df["층"]
del sum_df["부번"]
del sum_df["본번"]
del sum_df["단지명"]

# %%
sum_df.head(50)
# Out:
#                            시군구 전월세구분 전용면적(㎡)    계약년월 계약일         보증금(만원)  \
# result_op_df 0   서울특별시 강남구 개포동    월세   36.96  201905   9           2,000
#              1   서울특별시 강남구 개포동    전세   36.96  201911   1          20,000
#              2   서울특별시 강남구 개포동    전세   22.12  201911  20          18,000
#              3   서울특별시 강남구 개포동    전세   37.41  201911   7          28,000
#              4   서울특별시 강남구 개포동    전세   37.55  201902  16          16,000
#              5   서울특별시 강남구 개포동    전세   31.91  201903   4          15,000
#              6   서울특별시 강남구 개포동    전세   32.44  201903   5          14,000
#              7   서울특별시 강남구 개포동    전세   31.91  201903  20          17,000
#              8   서울특별시 강남구 개포동    전세   31.91  201903  29          16,000
#              9   서울특별시 강남구 개포동    전세   32.44  201904  13          14,000
#              10  서울특별시 강남구 개포동    월세   31.91  201905  17           1,000
#              11  서울특별시 강남구 개포동    월세   32.44  201905  27           1,000
# ...

# %%
sum_df["시군구"].plot(kind="bar", grid=True, figsize=(10,5), color="blue")
# Out:
# Empty DataFrame
# Columns: [시군구, 번지, 본번, 부번, 단지명, 전월세구분, 전용면적(㎡), 계약년월, 계약일, 보증금(만원), 월세(만원), 층, 건축년도, 도로명]
# Index: []
